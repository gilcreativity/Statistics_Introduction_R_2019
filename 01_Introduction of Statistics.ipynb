# %% [markdown]
# # 01. Introduction of Statistics
# ---

# %% [markdown]
# # 통계학
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 기술적 통계학
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 추론적 통계학
# ---

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 추론 통계 가정 및 방법

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # 참고) DGP

# %% [markdown]
# ![image.png](attachment:image.png)
